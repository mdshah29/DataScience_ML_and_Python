# %%
import pandas as pd
import numpy as np

inputfile = 'movies.xls'
df1 = pd.read_excel(inputfile, sheetnumber=0, inxed_col=0)
df2 = pd.read_excel(inputfile, sheetnumber=2, inxed_col=0)

df1.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# 1          1.33   100000.0       3000000.0  ...                        2
# 2          1.33   245000.0             NaN  ...                       81
# 3          1.33  6000000.0         26435.0  ...                      136
# 4          1.33        NaN          9950.0  ...                      426
#
#   Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                       22                      9.0
# 1                        2                      0.0
# 2                       12                      6.0
# 3                       23                     18.0
# 4                       20                      3.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                         481                     691                      1
# 1                           4                       0                      1
# 2                         108                     226                      0
# 3                         203                   12000                      1
# 4                         455                     926                      1
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       10718                88                69.0         8.0
# 1           5                 1                 1.0         4.8
# 2        4849                45                48.0         8.3
# 3      111841               413               260.0         8.3
# 4        7431                84                71.0         8.0
#
# [5 rows x 25 columns]

# %%
df2.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# 1          1.33   100000.0       3000000.0  ...                        2
# 2          1.33   245000.0             NaN  ...                       81
# 3          1.33  6000000.0         26435.0  ...                      136
# 4          1.33        NaN          9950.0  ...                      426
#
#   Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                       22                      9.0
# 1                        2                      0.0
# 2                       12                      6.0
# 3                       23                     18.0
# 4                       20                      3.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                         481                     691                      1
# 1                           4                       0                      1
# 2                         108                     226                      0
# 3                         203                   12000                      1
# 4                         455                     926                      1
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       10718                88                69.0         8.0
# 1           5                 1                 1.0         4.8
# 2        4849                45                48.0         8.3
# 3      111841               413               260.0         8.3
# 4        7431                84                71.0         8.0
#
# [5 rows x 25 columns]

# %%
df1.shape
# Out:
# (1338, 25)

# %%
df1.equals(df2)
# Out:
# True

# %%
comparison_values = df1.values == df2.values
print (comparison_values)
# Out:
# [[ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  ...
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]]

# %%
import numpy as np
rows,cols=np.where(comparison_values==False)

# %%
for item in zip(rows,cols):
    df1.iloc[item[0], item[1]] = '{} --> {}'.format(df1.iloc[item[0], item[1]],df2.iloc[item[0], item[1]])

# %%
df1
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                             Genres     Language  Country Content Rating  \
# 0                Drama|History|War  nan --> nan      USA      Not Rated
# 1                      Crime|Drama  nan --> nan      USA    nan --> nan
# 2                Drama|Romance|War  nan --> nan      USA      Not Rated
# 3                     Drama|Sci-Fi       German  Germany      Not Rated
# 4              Crime|Drama|Romance       German  Germany      Not Rated
# ...                            ...          ...      ...            ...
# 1333                         Drama      English      USA              R
# 1334                 Action|Sci-Fi      English      USA              R
# 1335    Comedy|Drama|Romance|Sport      English      USA              R
# 1336  Action|Comedy|Sci-Fi|Western      English      USA          PG-13
# 1337       Action|Adventure|Sci-Fi      English      USA          PG-13
#
#       Duration Aspect Ratio       Budget Gross Earnings  ...  \
# 0          123         1.33       385907    nan --> nan  ...
# 1          110         1.33       100000          3e+06  ...
# 2          151         1.33       245000    nan --> nan  ...
# 3          145         1.33        6e+06          26435  ...
# 4          110         1.33  nan --> nan           9950  ...
# ...        ...          ...          ...            ...  ...
# 1333       111         1.85       500000         985341  ...
# 1334        83         1.85      2.4e+07    1.04312e+07  ...
# 1335       106         1.85      1.6e+07    5.28856e+07  ...
# 1336       106         1.85      1.7e+08    1.13745e+08  ...
# 1337       100         2.35        3e+07    1.15761e+07  ...
#
#      Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 0                         436                       22
# 1                           2                        2
# 2                          81                       12
# 3                         136                       23
# 4                         426                       20
# ...                       ...                      ...
# 1333                      980                      505
# 1334                     2000                      577
# 1335                    23000                      255
# 1336                    10000                     4000
# 1337                      811                      586
#
#      Facebook Likes - Actor 3 Facebook Likes - cast Total  \
# 0                           9                         481
# 1                           0                           4
# 2                           6                         108
# 3                          18                         203
# 4                           3                         455
# ...                       ...                         ...
# 1333                      482                        3166
# 1334                      485                        4024
# 1335                       35                       23369
# 1336                      582                       15870
# 1337                      362                        2497
#
#       Facebook likes - Movie  Facenumber in posters  User Votes  \
# 0                        691                      1       10718
# 1                          0                      1           5
# 2                        226                      0        4849
# 3                      12000                      1      111841
# 4                        926                      1        7431
# ...                      ...                    ...         ...
# 1333                     180                      0        3479
# 1334                     401                      0       24216
# 1335                       0                      0       35312
# 1336                       0                      2      129601
# 1337                     858                      3       14747
#
#      Reviews by Users  Reviews by Crtiics  IMDB Score
# 0                  88                  69         8.0
# 1                   1                   1         4.8
# 2                  45                  48         8.3
# 3                 413                 260         8.3
# 4                  84                  71         8.0
# ...               ...                 ...         ...
# 1333               87                  54         7.3
# 1334              162                  75         4.1
# 1335              267                  67         6.4
# 1336              648                  85         4.8
# 1337              338                  85         4.1
#
# [1338 rows x 25 columns]
